# %% [markdown]
# ### Zomato Recommendation System

# %%
# Importing Libraries

import numpy as np
import pandas as pd

# %% [markdown]
# #### Loading the dataset

# %%
df = pd.read_csv("zomato.csv")

# %%
print(df.shape)
df.head()
# Out:
# (51717, 17)
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %% [markdown]
# #### Data Cleaning and Feature Engineering

# %%
# Deleting Columns which are not necessary
data = df.drop(["url", "address", "dish_liked", "phone", "menu_item", "reviews_list","listed_in(type)","listed_in(city)"], axis=1)

# %%
# Removing the Duplicates
print(data.duplicated().sum())
data = data.drop_duplicates()
# Out:
# 28755

# %%
# Removing the NULL values
print(data.isnull().sum())
data = data.dropna(how="any")
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           2724
# votes                             0
# location                         11
# rest_type                        99
# cuisines                         29
# approx_cost(for two people)     143
# dtype: int64

# %%
# Rename Columns
data.rename(columns={'approx_cost(for two people)':'cost'},inplace=True)
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'cuisines', 'cost'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20064 entries, 0 to 51677
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          20064 non-null  object
#  1   online_order  20064 non-null  object
#  2   book_table    20064 non-null  object
#  3   rate          20064 non-null  object
#  4   votes         20064 non-null  int64
#  5   location      20064 non-null  object
#  6   rest_type     20064 non-null  object
#  7   cuisines      20064 non-null  object
#  8   cost          20064 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# #### Transformations

# %%
# Cost
data["cost"] = data["cost"].apply(lambda x : x.replace(",","")).astype(np.float32)

# %%
# Rate
data["rate"] = data["rate"].apply(lambda x : x.replace("/5",""))
l1 = list(data[data["rate"] == "NEW"].index)
l2 = list(data[data["rate"] == '-'].index)
l1.extend(l2)
l = l1
data = data.drop(l)
data["rate"] = data["rate"].astype(np.float32)

# %%
# Online_Order and Book_Table
data["online_order"] = data["online_order"].replace(("Yes","No"),(True,False))
data["book_table"] = data["book_table"].replace(("Yes","No"),(True,False))

# %%
# Lowercase Conversion
data["location"] = data["location"].apply(lambda x : x.lower())
data["rest_type"] = data["rest_type"].apply(lambda x : x.lower())
data["cuisines"] = data["cuisines"].apply(lambda x : x.lower())

# %%
print("No of Null Values : ", data.isnull().sum().sum())
data.head()
# Out:
# No of Null Values :  0
#                     name  online_order  book_table  rate  votes      location  \
# 0                  Jalsa          True        True   4.1    775  banashankari
# 1         Spice Elephant          True       False   4.1    787  banashankari
# 2        San Churro Cafe          True       False   3.8    918  banashankari
# 3  Addhuri Udupi Bhojana         False       False   3.7     88  banashankari
# 4          Grand Village         False       False   3.8    166  basavanagudi
#
#              rest_type                        cuisines   cost
# 0        casual dining  north indian, mughlai, chinese  800.0
# 1        casual dining     chinese, north indian, thai  800.0
# 2  cafe, casual dining          cafe, mexican, italian  800.0
# 3          quick bites      south indian, north indian  300.0
# 4        casual dining        north indian, rajasthani  600.0

# %% [markdown]
# ### Recommendation System

# %%
df_filer = data.sample(frac = 0.25)
print(df_filer.shape)
# Out:
# (4784, 9)

# %%
df_filter = df_filer.set_index("name")

# %%
indices = pd.Series(df_filter.index)

# %%
indices.head()
# Out:
# 0                      Maiyas
# 1                   Tastebuds
# 2    Mojo Pizza - 2X Toppings
# 3             Nandhana Palace
# 4                   Hot Brixx
# Name: name, dtype: object

# %%
# Creating Tf-Idf matrix
from sklearn.feature_extraction.text import TfidfVectorizer

TFIDF = TfidfVectorizer(ngram_range=(1, 2), stop_words='english')
cuisine_matrix = TFIDF.fit_transform(df_filter["cuisines"])

# %%
cost_matrix = pd.concat([df_filter["cost"],df_filter["rate"]],axis=1).values

# %%
print("Cuisine ",cuisine_matrix.shape)
print("Cost and Rate ",cost_matrix.shape)
# Out:
# Cuisine  (4784, 924)
# Cost and Rate  (4784, 2)

# %%
from scipy.sparse import hstack

matrix = hstack((cuisine_matrix,cost_matrix))

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarities = cosine_similarity(matrix)

# %%
def recommend(name, n, cosine_similarities=cosine_similarities):
    restaurant = []
    
    # Index of the Restaurant
    idx = indices[indices == name].index[0]
    
    # Restaurants with similar score
    score = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Top n Indexes
    top = list(score.iloc[0:n].index)
    
    # Covert Top to df
    top = df_filter.iloc[top]
    
    return top

# %%
df_filter.loc[indices[0]]
# Out:
# online_order                                                 True
# book_table                                                  False
# rate                                                          3.9
# votes                                                         291
# location                                             malleshwaram
# rest_type                                     quick bites, bakery
# cuisines        south indian, north indian, chinese, bakery, d...
# cost                                                        300.0
# Name: Maiyas, dtype: object

# %%
recommend(indices[0],20)
# Out:
#                        online_order  book_table  rate  votes  \
# name
# Maiyas                         True       False   3.9    291
# Bhavani Restaurant            False       False   3.9    100
# Atithi Aramane Veg             True       False   3.9     49
# Upahara Mandira                True       False   3.9     24
# Matru Sagar                    True       False   4.0    332
# Adithya                        True       False   4.0    334
# Adithya                        True       False   4.0    332
# Matru Sagar                    True       False   4.1    327
# Sri Ayodhya Veg               False       False   3.6     24
# New Sagar Fast Food           False       False   3.6     21
# Utsava Grand                  False       False   3.6     14
# Sri Ayodhya Veg               False       False   3.6     24
# Dhanalakshmi Grand             True       False   4.0     71
# Dhanalakshmi Grand             True       False   4.0     73
# Painted Platters              False       False   3.9     38
# Brownie Points                 True       False   3.8     26
# Sugar Rush                    False       False   3.8     39
# Addhuri Udupi Bhojana         False       False   3.7     88
# New Udupi Grand                True       False   3.5     47
# Happy Endings                  True       False   4.1    180
#
#                                          location               rest_type  \
# name
# Maiyas                               malleshwaram     quick bites, bakery
# Bhavani Restaurant                   basavanagudi             quick bites
# Atithi Aramane Veg                      bellandur             quick bites
# Upahara Mandira                        hbr layout             quick bites
# Matru Sagar                          kalyan nagar             quick bites
# Adithya                                  jp nagar             quick bites
# Adithya                                  jp nagar             quick bites
# Matru Sagar                          kalyan nagar             quick bites
# Sri Ayodhya Veg                     vasanth nagar             quick bites
# New Sagar Fast Food                   rajajinagar             quick bites
# Utsava Grand                             majestic             quick bites
# Sri Ayodhya Veg                     vasanth nagar             quick bites
# Dhanalakshmi Grand                   malleshwaram             quick bites
# Dhanalakshmi Grand                   malleshwaram             quick bites
# Painted Platters                           ulsoor                  bakery
# Brownie Points              koramangala 4th block                  bakery
# Sugar Rush                           banashankari                  bakery
# Addhuri Udupi Bhojana                banashankari             quick bites
# New Udupi Grand                          jp nagar             quick bites
# Happy Endings          itpl main road, whitefield  bakery, dessert parlor
#
#                                                                 cuisines  \
# name
# Maiyas                 south indian, north indian, chinese, bakery, d...
# Bhavani Restaurant                   south indian, north indian, chinese
# Atithi Aramane Veg                   south indian, north indian, chinese
# Upahara Mandira                      south indian, north indian, chinese
# Matru Sagar                          south indian, north indian, chinese
# Adithya                              south indian, north indian, chinese
# Adithya                              south indian, north indian, chinese
# Matru Sagar                          south indian, north indian, chinese
# Sri Ayodhya Veg                      south indian, north indian, chinese
# New Sagar Fast Food                  south indian, north indian, chinese
# Utsava Grand                         south indian, north indian, chinese
# Sri Ayodhya Veg                      south indian, north indian, chinese
# Dhanalakshmi Grand                            south indian, north indian
# Dhanalakshmi Grand                            south indian, north indian
# Painted Platters                                        bakery, desserts
# Brownie Points                                          bakery, desserts
# Sugar Rush                                              bakery, desserts
# Addhuri Udupi Bhojana                         south indian, north indian
# New Udupi Grand                      south indian, north indian, chinese
# Happy Endings                                           bakery, desserts
#
#                         cost
# name
# Maiyas                 300.0
# Bhavani Restaurant     300.0
# Atithi Aramane Veg     300.0
# Upahara Mandira        300.0
# Matru Sagar            300.0
# Adithya                300.0
# Adithya                300.0
# Matru Sagar            300.0
# Sri Ayodhya Veg        300.0
# New Sagar Fast Food    300.0
# Utsava Grand           300.0
# Sri Ayodhya Veg        300.0
# Dhanalakshmi Grand     300.0
# Dhanalakshmi Grand     300.0
# Painted Platters       300.0
# Brownie Points         300.0
# Sugar Rush             300.0
# Addhuri Udupi Bhojana  300.0
# New Udupi Grand        300.0
# Happy Endings          300.0
