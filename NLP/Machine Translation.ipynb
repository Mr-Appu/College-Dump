# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
with open("/kaggle/input/tamiltxt/tam.txt", encoding="utf8") as f:
    data = f.read().split("\n")

X_txt = []
y_txt = []

X_voc = set()
y_voc = set()
    
for line in data:
    # Skip In-Valid Seq
    if(len(line.split("\t")) != 3):
        continue
    
    target, inp, _ = line.split("\t")
    target = "\t" + target + "\n" # "\t" -> Start Seq, "\n" -> End Seq
    
    X_txt.append(inp)
    y_txt.append(target)
    
    X_voc.update(set(inp))
    y_voc.update(set(target))

# %%
print("No of Records : ", len(X_txt), end="\n\n")

X_voc = sorted(list(X_voc))
y_voc = sorted(list(y_voc))

print("Vocab Size of Input tok : ", len(X_voc))
print("vocab Size of Output tok : ", len(y_voc), end="\n\n")

max_encoder = max([len(t) for t in X_txt])
max_decoder = max([len(t) for t in y_txt])

print("Max Seq length for input : ", max_encoder)
print("Max Seq length for output : ", max_decoder)
# Out:
# No of Records :  201
#
# Vocab Size of Input tok :  52
# vocab Size of Output tok :  55
#
# Max Seq length for input :  109
# Max Seq length for output :  96

# %% [markdown]
# ### Tokenization

# %%
input_tok_enc = dict([(char, i) for i, char in enumerate(X_voc)])
input_tok_dec = dict([(i, char) for i, char in enumerate(X_voc)])

target_tok_enc = dict([(char, i) for i, char in enumerate(y_voc)])
target_tok_dec = dict([(i, char) for i, char in enumerate(y_voc)])

# %%
X = [[input_tok_enc[char] for char in text] for text in X_txt]
y = [[target_tok_enc[char] for char in text] for text in y_txt]

# %% [markdown]
# ### Padding

# %%
from tensorflow.keras.utils import pad_sequences

X = pad_sequences(X, maxlen=max_encoder, padding="post", value=input_tok_enc[' '])
y = pad_sequences(y, maxlen=max_decoder, padding="post", value=target_tok_enc[' '])
# Out:
# 2024-03-31 03:58:11.443475: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-31 03:58:11.443576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-31 03:58:11.586665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, CategoryEncoding

latent_dim = 256

# Encoder Block
encoder_inputs = Input(shape=(None, len(X_voc)))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

encoder_states = [state_h, state_c]

# Decoder Block
decoder_inputs = (Input(shape=(None, len(y_voc))))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(len(y_voc), activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
import tensorflow as tf

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None, 52)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None, 55)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 256),     │    316,416 │ input_layer[0][0] │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, None,     │    319,488 │ input_layer_1[0]… │
# │                     │ 256), (None,      │            │ lstm[0][1],       │
# │                     │ 256), (None,      │            │ lstm[0][2]        │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 55)  │     14,135 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 650,039 (2.48 MB)
#  Trainable params: 650,039 (2.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Model - Training

# %%
from sklearn.preprocessing import OneHotEncoder

encoder_input_data = np.zeros((len(X), max_encoder, len(X_voc)), dtype="float")
for i, line in enumerate(X):
    for j, k in enumerate(line):
        encoder_input_data[i][j][k] = 1.0
        
decoder_input_data = np.zeros((len(X), max_decoder, len(y_voc)), dtype="float")
decoder_target_data = np.zeros((len(X), max_decoder, len(y_voc)), dtype="float")
for i, line in enumerate(y):
    for j, k in enumerate(line):
        decoder_input_data[i, j, k] = 1.0
        if(j > 0):
            decoder_target_data[i, j-1, k] = 1.0
            
model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size=64, epochs=5000, validation_split=0.2)
# Out:
# Epoch 1/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.3394 - loss: 3.8919 - val_accuracy: 0.6519 - val_loss: 3.6119
# Epoch 2/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8102 - loss: 3.2701 - val_accuracy: 0.6509 - val_loss: 2.0635
# Epoch 3/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8114 - loss: 1.2451 - val_accuracy: 0.6509 - val_loss: 2.3600
# Epoch 4/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8104 - loss: 1.0974 - val_accuracy: 0.6468 - val_loss: 2.0770
# Epoch 5/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7396 - loss: 1.2493 - val_accuracy: 0.6532 - val_loss: 2.0739
# Epoch 6/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8123 - loss: 0.9811 - val_accuracy: 0.6509 - val_loss: 2.0031
# Epoch 7/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8108 - loss: 0.9832 - val_accuracy: 0.6509 - val_loss: 1.8279
# Epoch 8/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8095 - loss: 0.9556 - val_accuracy: 0.6509 - val_loss: 1.7042
# Epoch 9/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8093 - loss: 0.9655 - val_accuracy: 0.6509 - val_loss: 1.6614
# Epoch 10/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8097 - loss: 0.9510 - val_accuracy: 0.6509 - val_loss: 1.6618
# Epoch 11/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8087 - loss: 0.9092 - val_accuracy: 0.6509 - val_loss: 1.6894
# Epoch 12/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8075 - loss: 0.8908 - val_accuracy: 0.6509 - val_loss: 1.6802
# Epoch 13/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8098 - loss: 0.8510 - val_accuracy: 0.6509 - val_loss: 1.6169
# Epoch 14/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8089 - loss: 0.8163 - val_accuracy: 0.6512 - val_loss: 1.5510
# Epoch 15/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8131 - loss: 0.7763 - val_accuracy: 0.6491 - val_loss: 1.5497
# Epoch 16/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8087 - loss: 0.7521 - val_accuracy: 0.6479 - val_loss: 1.5806
# Epoch 17/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8061 - loss: 0.7374 - val_accuracy: 0.6504 - val_loss: 1.6190
# Epoch 18/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8103 - loss: 0.7217 - val_accuracy: 0.6504 - val_loss: 1.6487
# Epoch 19/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8095 - loss: 0.7164 - val_accuracy: 0.6514 - val_loss: 1.6737
# Epoch 20/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8091 - loss: 0.7109 - val_accuracy: 0.6468 - val_loss: 1.7224
# Epoch 21/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8045 - loss: 0.7103 - val_accuracy: 0.6499 - val_loss: 1.7078
# Epoch 22/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8090 - loss: 0.7039 - val_accuracy: 0.6509 - val_loss: 1.7417
# Epoch 23/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8110 - loss: 0.6976 - val_accuracy: 0.6509 - val_loss: 1.6982
# Epoch 24/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8090 - loss: 0.6998 - val_accuracy: 0.6509 - val_loss: 1.7760
# Epoch 25/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8095 - loss: 0.6973 - val_accuracy: 0.6509 - val_loss: 1.7015
# Epoch 26/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8099 - loss: 0.6926 - val_accuracy: 0.6509 - val_loss: 1.7462
# Epoch 27/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8097 - loss: 0.6921 - val_accuracy: 0.6542 - val_loss: 1.7185
# Epoch 28/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8117 - loss: 0.6921 - val_accuracy: 0.6542 - val_loss: 1.7057
# Epoch 29/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8117 - loss: 0.6889 - val_accuracy: 0.6542 - val_loss: 1.7240
# Epoch 30/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8139 - loss: 0.6862 - val_accuracy: 0.6542 - val_loss: 1.6718
# Epoch 31/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8123 - loss: 0.6896 - val_accuracy: 0.6542 - val_loss: 1.7261
# Epoch 32/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.
5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8841 - loss: 0.3561 - val_accuracy: 0.6895 - val_loss: 1.4847
# Epoch 352/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8852 - loss: 0.3594 - val_accuracy: 0.6923 - val_loss: 1.4617
# Epoch 353/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8847 - loss: 0.3505 - val_accuracy: 0.6850 - val_loss: 1.4894
# Epoch 354/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8887 - loss: 0.3481 - val_accuracy: 0.6895 - val_loss: 1.4919
# Epoch 355/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8867 - loss: 0.3500 - val_accuracy: 0.6949 - val_loss: 1.4471
# Epoch 356/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8892 - loss: 0.3456 - val_accuracy: 0.6872 - val_loss: 1.4987
# Epoch 357/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8888 - loss: 0.3442 - val_accuracy: 0.6829 - val_loss: 1.5400
# Epoch 358/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8875 - loss: 0.3438 - val_accuracy: 0.6827 - val_loss: 1.5070
# Epoch 359/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8904 - loss: 0.3407 - val_accuracy: 0.6944 - val_loss: 1.4389
# Epoch 360/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8899 - loss: 0.3419 - val_accuracy: 0.6900 - val_loss: 1.4356
# Epoch 361/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8892 - loss: 0.3439 - val_accuracy: 0.6939 - val_loss: 1.3802
# Epoch 362/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8882 - loss: 0.3413 - val_accuracy: 0.6890 - val_loss: 1.4288
# Epoch 363/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8931 - loss: 0.3328 - val_accuracy: 0.6875 - val_loss: 1.4391
# Epoch 364/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8911 - loss: 0.3331 - val_accuracy: 0.6905 - val_loss: 1.4372
# Epoch 365/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8897 - loss: 0.3363 - val_accuracy: 0.6946 - val_loss: 1.3868
# Epoch 366/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8886 - loss: 0.3377 - val_accuracy: 0.6926 - val_loss: 1.4071
# Epoch 367/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8919 - loss: 0.3318 - val_accuracy: 0.6872 - val_loss: 1.4174
# Epoch 368/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8886 - loss: 0.3388 - val_accuracy: 0.6880 - val_loss: 1.4261
# Epoch 369/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8932 - loss: 0.3328 - val_accuracy: 0.6878 - val_loss: 1.4698
# Epoch 370/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8925 - loss: 0.3338 - val_accuracy: 0.6883 - val_loss: 1.5009
# Epoch 371/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8916 - loss: 0.3342 - val_accuracy: 0.6875 - val_loss: 1.4347
# Epoch 372/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8905 - loss: 0.3328 - val_accuracy: 0.6883 - val_loss: 1.4720
# Epoch 373/5000
# ...
# Epoch 4878/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6715 - val_loss: 3.4824
# Epoch 4879/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6707 - val_loss: 3.4832
# Epoch 4880/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4870
# Epoch 4881/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6707 - val_loss: 3.4909
# Epoch 4882/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6715 - val_loss: 3.4934
# Epoch 4883/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6715 - val_loss: 3.4941
# Epoch 4884/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6715 - val_loss: 3.4927
# Epoch 4885/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6710 - val_loss: 3.4912
# Epoch 4886/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6712 - val_loss: 3.4898
# Epoch 4887/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6710 - val_loss: 3.4871
# Epoch 4888/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6712 - val_loss: 3.4861
# Epoch 4889/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6710 - val_loss: 3.4853
# Epoch 4890/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6705 - val_loss: 3.4860
# Epoch 4891/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4893
# Epoch 4892/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4922
# Epoch 4893/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6712 - val_loss: 3.4946
# Epoch 4894/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6712 - val_loss: 3.4935
# Epoch 4895/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6710 - val_loss: 3.4923
# Epoch 4896/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6707 - val_loss: 3.4861
# Epoch 4897/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6707 - val_loss: 3.4856
# Epoch 4898/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4867
# Epoch 4899/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6702 - val_loss: 3.4839
# Epoch 4900/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6705 - val_loss: 3.4859
# Epoch 4901/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6710 - val_loss: 3.4918
# Epoch 4902/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6710 - val_loss: 3.4921
# Epoch 4903/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6705 - val_loss: 3.4884
# Epoch 4904/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4886
# Epoch 4905/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6702 - val_loss: 3.4877
# Epoch 4906/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4844
# Epoch 4907/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4878
# Epoch 4908/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4931
# Epoch 4909/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4933
# Epoch 4910/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4895
# Epoch 4911/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4890
# Epoch 4912/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6702 - val_loss: 3.4895
# Epoch 4913/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4904
# Epoch 4914/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4925
# Epoch 4915/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4912
# Epoch 4916/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6695 - val_loss: 3.4868
# Epoch 4917/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6695 - val_loss: 3.4861
# Epoch 4918/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6695 - val_loss: 3.4892
# Epoch 4919/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4899
# Epoch 4920/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4901
# Epoch 4921/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4909
# Epoch 4922/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4904
# Epoch 4923/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4886
# Epoch 4924/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4887
# Epoch 4925/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4873
# Epoch 4926/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4869
# Epoch 4927/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4902
# Epoch 4928/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4915
# Epoch 4929/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4906
# Epoch 4930/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6695 - val_loss: 3.4894
# Epoch 4931/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4885
# Epoch 4932/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4868
# Epoch 4933/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4882
# Epoch 4934/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4903
# Epoch 4935/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4912
# Epoch 4936/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4912
# Epoch 4937/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4911
# Epoch 4938/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4901
# Epoch 4939/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6697 - val_loss: 3.4892
# Epoch 4940/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6697 - val_loss: 3.4889
# Epoch 4941/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4885
# Epoch 4942/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4884
# Epoch 4943/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4901
# Epoch 4944/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4916
# Epoch 4945/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6700 - val_loss: 3.4908
# Epoch 4946/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6697 - val_loss: 3.4928
# Epoch 4947/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6700 - val_loss: 3.4928
# Epoch 4948/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6700 - val_loss: 3.4916
# Epoch 4949/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6700 - val_loss: 3.4932
# Epoch 4950/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6702 - val_loss: 3.4950
# Epoch 4951/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6707 - val_loss: 3.4893
# Epoch 4952/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6702 - val_loss: 3.4887
# Epoch 4953/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6705 - val_loss: 3.4932
# Epoch 4954/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6695 - val_loss: 3.4941
# Epoch 4955/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.4940
# Epoch 4956/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6707 - val_loss: 3.4928
# Epoch 4957/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6712 - val_loss: 3.4904
# Epoch 4958/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0048 - val_accuracy: 0.6710 - val_loss: 3.4925
# Epoch 4959/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6720 - val_loss: 3.5008
# Epoch 4960/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0058 - val_accuracy: 0.6712 - val_loss: 3.5317
# Epoch 4961/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6720 - val_loss: 3.5399
# Epoch 4962/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0050 - val_accuracy: 0.6710 - val_loss: 3.5345
# Epoch 4963/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0053 - val_accuracy: 0.6730 - val_loss: 3.5067
# Epoch 4964/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0048 - val_accuracy: 0.6710 - val_loss: 3.5045
# Epoch 4965/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0052 - val_accuracy: 0.6700 - val_loss: 3.5318
# Epoch 4966/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0051 - val_accuracy: 0.6692 - val_loss: 3.5571
# Epoch 4967/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6684 - val_loss: 3.5704
# Epoch 4968/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6700 - val_loss: 3.5430
# Epoch 4969/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6705 - val_loss: 3.5215
# Epoch 4970/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0045 - val_accuracy: 0.6705 - val_loss: 3.5010
# Epoch 4971/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0050 - val_accuracy: 0.6692 - val_loss: 3.5029
# Epoch 4972/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0049 - val_accuracy: 0.6705 - val_loss: 3.5137
# Epoch 4973/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6717 - val_loss: 3.5239
# Epoch 4974/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6728 - val_loss: 3.5232
# Epoch 4975/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0049 - val_accuracy: 0.6712 - val_loss: 3.5297
# Epoch 4976/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0048 - val_accuracy: 0.6700 - val_loss: 3.5296
# Epoch 4977/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6692 - val_loss: 3.5123
# Epoch 4978/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6710 - val_loss: 3.4764
# Epoch 4979/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0048 - val_accuracy: 0.6702 - val_loss: 3.4500
# Epoch 4980/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0050 - val_accuracy: 0.6715 - val_loss: 3.4359
# Epoch 4981/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6738 - val_loss: 3.4396
# Epoch 4982/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9896 - loss: 0.0046 - val_accuracy: 0.6730 - val_loss: 3.4474
# Epoch 4983/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6723 - val_loss: 3.4536
# Epoch 4984/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0047 - val_accuracy: 0.6733 - val_loss: 3.4663
# Epoch 4985/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9896 - loss: 0.0051 - val_accuracy: 0.6725 - val_loss: 3.4732
# Epoch 4986/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0044 - val_accuracy: 0.6723 - val_loss: 3.4609
# Epoch 4987/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0052 - val_accuracy: 0.6748 - val_loss: 3.4403
# Epoch 4988/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0074 - val_accuracy: 0.6756 - val_loss: 3.4827
# Epoch 4989/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9896 - loss: 0.0049 - val_accuracy: 0.6702 - val_loss: 3.5473
# Epoch 4990/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9895 - loss: 0.0048 - val_accuracy: 0.6667 - val_loss: 3.5954
# Epoch 4991/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0057 - val_accuracy: 0.6720 - val_loss: 3.5726
# Epoch 4992/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0053 - val_accuracy: 0.6738 - val_loss: 3.5026
# Epoch 4993/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0051 - val_accuracy: 0.6740 - val_loss: 3.5063
# Epoch 4994/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9896 - loss: 0.0058 - val_accuracy: 0.6738 - val_loss: 3.3727
# Epoch 4995/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9895 - loss: 0.0057 - val_accuracy: 0.6761 - val_loss: 3.3306
# Epoch 4996/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9895 - loss: 0.0054 - val_accuracy: 0.6771 - val_loss: 3.3517
# Epoch 4997/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0058 - val_accuracy: 0.6763 - val_loss: 3.3016
# Epoch 4998/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0055 - val_accuracy: 0.6771 - val_loss: 3.2212
# Epoch 4999/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9895 - loss: 0.0054 - val_accuracy: 0.6799 - val_loss: 3.1952
# Epoch 5000/5000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0052 - val_accuracy: 0.6806 - val_loss: 3.2308

# %% [markdown]
# #### Load Model Weights

# %%
model.save('tam2eng.keras')

# %% [markdown]
# #### Inference Model

# %%
encoder_inputs = model.input[0]
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output # Lstm 1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]
decoder_state_input_h = Input(shape=(latent_dim, ))
decoder_state_input_c = Input(shape=(latent_dim, ))
decoder_state_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3] # Lstm 2
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs, initial_state=decoder_state_inputs)
decoder_states = [state_h_dec, state_c_dec]

decoder_dense = model.layers[4] # Dense Layer
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_state_inputs, [decoder_outputs] + decoder_states)

# %%
def decode_seq(input_seq):
    
    # Encoder
    state_value = encoder_model.predict(input_seq, verbose=0)
    
    target_seq = np.zeros((1, 1, len(y_voc)))
    target_seq[0, 0, target_tok_enc["\t"]] = 1.0
    
    stop = False
    decode_sent = ""
    
    while not stop:
        
        output_tok, h, c = decoder_model.predict([target_seq] + state_value, verbose=0)
        
        sample_token_idx = np.argmax(output_tok[0, -1, :])
        sample_char = target_tok_dec[sample_token_idx]
        
        decode_sent += sample_char
        
        if sample_char == "\n" or len(decode_sent) > max_decoder:
            stop = True
            
        target_seq = np.zeros((1, 1, len(y_voc)))
        target_seq[0, 0, sample_token_idx] = 1.0
        
        state_value = [h, c]
        
    return decode_sent

# %%
for i in range(10):
    
    input_seq = encoder_input_data[i: i+1]
    d_seq = decode_seq(input_seq)
    
    print("Input Seq : ", X_txt[i])
    print("Output Seq : ", d_seq)
# Out:
# Input Seq :  நான் தூங்கினேன்.
# Output Seq :  I slept.
#
# Input Seq :  அமைதியாக இருங்கள்
# Output Seq :  Calm down.
#
# Input Seq :  நான் நடப்பேன்.
# Output Seq :  I'll walk.
#
# Input Seq :  அவன் யார்?
# Output Seq :  Who is he?
#
# Input Seq :  யாருக்குத் தெரியும்?
# Output Seq :  Who knows?
#
# Input Seq :  அவள் சிரித்தாள்
# Output Seq :  She smiled.
#
# Input Seq :  என்னிடம் பேசு
# Output Seq :  Talk to me!
#
# Input Seq :  அவள் யார்?
# Output Seq :  Who is she?
#
# Input Seq :  போய் தூங்கு
# Output Seq :  Go to sleep.
#
# Input Seq :  மழை பெய்யலாம்
# Output Seq :  It may rain.

# %% [markdown]
# ### Testing on UnSeen Data

# %%
def inf_testing(text):
    # Tokenize
    tok = [input_tok_enc.get(char, input_tok_enc[" "]) for char in text]
    
    # Encoder Input Fmt
    encoder_inp_seq = np.zeros((1, len(tok), len(X_voc)), dtype="float")
    for i, j in enumerate(tok):
        encoder_inp_seq[0][i][j] = 1.0
        
    output = decode_seq(encoder_inp_seq)
    
    print("Input : ", text)
    print("Output : ", output)
    

lst = ["நான் மிகவும் சந்த ாஷமாக இருக்கிதேன", "அது அவசியமில்லை", "தயவுசெய்து அல மீண்டும் சசய்யவும", "அது ஒரு நல்ை தயாசலை", "அவர்கள் ஒன்ோக தவலை சசய்ய ஒப்புக்சகாண்டைர"]
for sent in lst:
    inf_testing(sent)
# Out:
# Input :  நான் மிகவும் சந்த ாஷமாக இருக்கிதேன
# Output :  I had to dom up.
#
# Input :  அது அவசியமில்லை
# Output :  Whe ridst.
#
# Input :  தயவுசெய்து அல மீண்டும் சசய்யவும
# Output :  Te ma m CD  lock.
#
# Input :  அது ஒரு நல்ை தயாசலை
# Output :  Don'd beaghrs.
#
# Input :  அவர்கள் ஒன்ோக தவலை சசய்ய ஒப்புக்சகாண்டைர
# Output :  When can we ut?
